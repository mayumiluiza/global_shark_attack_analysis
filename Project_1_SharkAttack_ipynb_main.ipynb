# %% [markdown]
# <a href="https://colab.research.google.com/github/mayumiluiza/shark_attack/blob/main/Project_1_SharkAttack_ipynb_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importando bibliotecas
import pandas as pd
import numpy as np
import re

# %%
#Função para abrir arquivo do google sheets
def read_from_gsheets(spreadsheet):
    """
    Transform url into csv 
    """
    working_spreadsheet = spreadsheet.replace('/edit?usp=sharing','/export?format=csv')
    
    return pd.read_csv(working_spreadsheet)

# %%
#Abrindo arquivo do google sheets
sharkattack_main = read_from_gsheets('https://docs.google.com/spreadsheets/d/1tFrVsabcTh4J-T6par8RYUFSvPRmVCjj/edit?usp=sharing&ouid=112931314534247376345&rtpof=true&sd=true')

# %%
#Limpando colunas e linhas extras que não são originárias da planilha oficial
sharkattack_main = sharkattack_main.iloc[:6840, :15]
sharkattack_main
# Out:
#              Date  Year        Type             Country               Area  \
# 0     25-Mar-2023  2023  Unprovoked                 USA            Florida
# 1     22-Mar-2023  2023  Unprovoked           AUSTRALIA  Western Australia
# 2     19-Mar-2023  2023  Unprovoked                 USA             Hawaii
# 3     17-Mar-2023  2023  Unprovoked              MEXICO       Quintana Roo
# 4     16-Mar-2023  2023  Unprovoked           AUSTRALIA  Western Australia
# ...           ...   ...         ...                 ...                ...
# 6835  Before 1903  0000  Unprovoked           AUSTRALIA  Western Australia
# 6836  Before 1903  0000  Unprovoked           AUSTRALIA  Western Australia
# 6837    1900-1905  0000  Unprovoked                 USA     North Carolina
# 6838    1883-1889  0000  Unprovoked              PANAMA                NaN
# 6839    1845-1853  0000  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                         Location      Activity  \
# 0     Blue Fish Channel, Key West, Monroe County  Kite-Surfing
# 1                                   Delta Island        Wading
# 2                                Anaehoomalu Bay      Swimming
# 3                                         Cancún      Swimming
# 4                                 Cheynes Beach     Surf-sking
# ...                                          ...           ...
# 6835                                 Roebuck Bay        Diving
# 6836                                         NaN  Pearl diving
# 6837                              Ocracoke Inlet      Swimming
# 6838                        Panama Bay 8ºN, 79ºW           NaN
# 6839         Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   Age  \
# 0      Kevin  Carlton Scott    M   67
# 1               Adam Norton    M  30s
# 2                      male    M   60
# 3             Dillon Armijo    M   10
# 4                    female    F  NaN
# ...                     ...  ...  ...
# 6835                   male    M  NaN
# 6836                  Ahmun    M  NaN
# 6837  Coast Guard personnel    M  NaN
# 6838        Jules Patterson    M  NaN
# 6839                   male    M   15
#
#                                                  Injury Fatal (Y/N)   Time  \
# 0                              Lacertions to right calf           N  14h00
# 1                       Lower left leg and foot injured           N  18h00
# 2                              Left hand and  left leg.           N  12h30
# 3                           Significant  injury to leg            N    NaN
# 4                                                   NaN           N  08h00
# ...                                                 ...         ...    ...
# 6835                                              FATAL           Y    NaN
# 6836                                              FATAL           Y    NaN
# 6837                                              FATAL           Y    NaN
# 6838                                              FATAL           Y    NaN
# 6839  FATAL. "Shark bit him in half, carrying away t...           Y    NaN
#
#             Species                  Investigator or Source
# 0                NaN                  Yahoo News, 3/28/2023
# 1                NaN                        A. Currie, GSAF
# 2                NaN                       Khon2, 3/19/2023
# 3                NaN                     Denver7, 3/29/2023
# 4     5m to 6m shark                         B. Myatt, GSAF
# ...              ...                                    ...
# 6835             NaN       H. Taunton; N. Bartlett,  p. 234
# 6836             NaN  H. Taunton; N. Bartlett,  pp. 233-234
# 6837             NaN   F. Schwartz, p.23; C. Creswell, GSAF
# 6838             NaN                    The Sun, 10/20/1938
# 6839             NaN                             S.W. Baker
#
# [6840 rows x 15 columns]

# %%
#Entendendo mais sobre a planilha
sharkattack_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6840 entries, 0 to 6839
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    6840 non-null   object
#  1   Year                    6838 non-null   object
#  2   Type                    6820 non-null   object
#  3   Country                 6790 non-null   object
#  4   Area                    6362 non-null   object
#  5   Location                6279 non-null   object
#  6   Activity                6257 non-null   object
#  7   Name                    6621 non-null   object
#  8   Sex                     6263 non-null   object
#  9   Age                     3869 non-null   object
#  10  Injury                  6805 non-null   object
#  11  Fatal (Y/N)             6282 non-null   object
#  12  Time                    3339 non-null   object
#  13  Species                 3757 non-null   object
#  14  Investigator or Source  6821 non-null   object
# dtypes: object(15)
# memory usage: 801.7+ KB

# %%
#Entendendo mais sobre a planilha
sharkattack_main.head
