# %% [markdown]
# <a href="https://colab.research.google.com/github/mayumiluiza/shark_attack/blob/main/Project_1_SharkAttack_limpezadedados_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importando bibliotecas
import pandas as pd
import numpy as np
import re
import datetime

# %%
#Função para abrir arquivo do google sheets
def read_from_gsheets(spreadsheet):
    """
    Transform url into csv 
    """
    working_spreadsheet = spreadsheet.replace('/edit?usp=sharing','/export?format=csv')
    
    return pd.read_csv(working_spreadsheet)

# %%
#Abrindo arquivo do google sheets
sharkattack_main = read_from_gsheets('https://docs.google.com/spreadsheets/d/1tFrVsabcTh4J-T6par8RYUFSvPRmVCjj/edit?usp=sharing&ouid=112931314534247376345&rtpof=true&sd=true')

# %%
#Limpando colunas e linhas extras que não são originárias da planilha oficial
sharkattack_main = sharkattack_main.iloc[:6840, :15]
sharkattack_main
# Out:
#              Date  Year        Type             Country               Area  \
# 0     25-Mar-2023  2023  Unprovoked                 USA            Florida
# 1     22-Mar-2023  2023  Unprovoked           AUSTRALIA  Western Australia
# 2     19-Mar-2023  2023  Unprovoked                 USA             Hawaii
# 3     17-Mar-2023  2023  Unprovoked              MEXICO       Quintana Roo
# 4     16-Mar-2023  2023  Unprovoked           AUSTRALIA  Western Australia
# ...           ...   ...         ...                 ...                ...
# 6835  Before 1903  0000  Unprovoked           AUSTRALIA  Western Australia
# 6836  Before 1903  0000  Unprovoked           AUSTRALIA  Western Australia
# 6837    1900-1905  0000  Unprovoked                 USA     North Carolina
# 6838    1883-1889  0000  Unprovoked              PANAMA                NaN
# 6839    1845-1853  0000  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                         Location      Activity  \
# 0     Blue Fish Channel, Key West, Monroe County  Kite-Surfing
# 1                                   Delta Island        Wading
# 2                                Anaehoomalu Bay      Swimming
# 3                                         Cancún      Swimming
# 4                                 Cheynes Beach     Surf-sking
# ...                                          ...           ...
# 6835                                 Roebuck Bay        Diving
# 6836                                         NaN  Pearl diving
# 6837                              Ocracoke Inlet      Swimming
# 6838                        Panama Bay 8ºN, 79ºW           NaN
# 6839         Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   Age  \
# 0      Kevin  Carlton Scott    M   67
# 1               Adam Norton    M  30s
# 2                      male    M   60
# 3             Dillon Armijo    M   10
# 4                    female    F  NaN
# ...                     ...  ...  ...
# 6835                   male    M  NaN
# 6836                  Ahmun    M  NaN
# 6837  Coast Guard personnel    M  NaN
# 6838        Jules Patterson    M  NaN
# 6839                   male    M   15
#
#                                                  Injury Fatal (Y/N)   Time  \
# 0                              Lacertions to right calf           N  14h00
# 1                       Lower left leg and foot injured           N  18h00
# 2                              Left hand and  left leg.           N  12h30
# 3                           Significant  injury to leg            N    NaN
# 4                                                   NaN           N  08h00
# ...                                                 ...         ...    ...
# 6835                                              FATAL           Y    NaN
# 6836                                              FATAL           Y    NaN
# 6837                                              FATAL           Y    NaN
# 6838                                              FATAL           Y    NaN
# 6839  FATAL. "Shark bit him in half, carrying away t...           Y    NaN
#
#             Species                  Investigator or Source
# 0                NaN                  Yahoo News, 3/28/2023
# 1                NaN                        A. Currie, GSAF
# 2                NaN                       Khon2, 3/19/2023
# 3                NaN                     Denver7, 3/29/2023
# 4     5m to 6m shark                         B. Myatt, GSAF
# ...              ...                                    ...
# 6835             NaN       H. Taunton; N. Bartlett,  p. 234
# 6836             NaN  H. Taunton; N. Bartlett,  pp. 233-234
# 6837             NaN   F. Schwartz, p.23; C. Creswell, GSAF
# 6838             NaN                    The Sun, 10/20/1938
# 6839             NaN                             S.W. Baker
#
# [6840 rows x 15 columns]

# %%
#Hipóteses para Validar
#Colunas Country, Date, Age, Sex
# Hipótese mãe: Existem diferença entre quantidade de ataques dependendo do sexo, estação do ano e idade
##1 Ataques de tubarão acontecem mais na primavera/outono do que verão/inverno 
##2 Ataques de tubarão acontecem mais em homens do que em mulheres 
##3 Ataques de tubarão acontecem mais em adultos (+18 anos) do que em crianças.

# %%
sharkattack_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6840 entries, 0 to 6839
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    6840 non-null   object
#  1   Year                    6838 non-null   object
#  2   Type                    6820 non-null   object
#  3   Country                 6790 non-null   object
#  4   Area                    6362 non-null   object
#  5   Location                6279 non-null   object
#  6   Activity                6257 non-null   object
#  7   Name                    6621 non-null   object
#  8   Sex                     6263 non-null   object
#  9   Age                     3869 non-null   object
#  10  Injury                  6805 non-null   object
#  11  Fatal (Y/N)             6282 non-null   object
#  12  Time                    3339 non-null   object
#  13  Species                 3757 non-null   object
#  14  Investigator or Source  6821 non-null   object
# dtypes: object(15)
# memory usage: 801.7+ KB

# %% [markdown]
# # Coluna Country

# %%
#COLUNA COUNTRY - Alterando valores NaN (part1.1: Descobrindo quantas linhas são NaN)
sharkattack_main.loc[sharkattack_main['Country'].isnull()]
len(sharkattack_main.loc[sharkattack_main['Country'].isnull()])
# Out:
# 50

# %%
#COLUNA COUNTRY - Alterando valores NaN (part1.2: Descobrindo quantas linhas são NaN)
sharkattack_main.loc[sharkattack_main['Country'].isnull()]
# Out:
#                       Date  Year          Type Country  \
# 572   Reported 13-Nov-2017  2017    Unprovoked     NaN
# 1038              Aug-2014  2014       Invalid     NaN
# 3474              Ca. 1983  1983    Unprovoked     NaN
# 3904              Nov-1970  1970    Unprovoked     NaN
# 3913           02-Aug-1970  1970       Invalid     NaN
# 3914            5-Jul-1970  1970    Unprovoked     NaN
# 3921              Apr-1970  1970      Provoked     NaN
# 3925            5-Feb-1970  1970    Unprovoked     NaN
# 3951              Aug-1969  1969    Unprovoked     NaN
# 4131           21-Oct-1965  1965    Unprovoked     NaN
# 4187           27-Sep-1964  1964       Invalid     NaN
# 4544           26-Jan-1960  1960  Sea Disaster     NaN
# 4757           13-Sep-1956  1956    Unprovoked     NaN
# 4792                  1956  1956  Sea Disaster     NaN
# 5027              Dec-1949  1949  Sea Disaster     NaN
# 5168           24-Oct-1944  1944  Sea Disaster     NaN
# 5229              Nov-1942  1942  Sea Disaster     NaN
# 5241              Jun-1942  1942    Unprovoked     NaN
# 5255                  1942  1942  Sea Disaster     NaN
# 5258                  1942  1942    Watercraft     NaN
# 5440  Reported 12-Apr-1935  1935    Unprovoked     NaN
# 5549  Reported 27-Apr-1931  1931    Unprovoked     NaN
# 5589  Reported 09-Dec-1929  1929    Unprovoked     NaN
# 5955           17-Jan-1909  1909       Invalid     NaN
# 6116  Reported 19-Sep-1898  1898    Unprovoked     NaN
# 6117  Reported 19-Sep-1898  1898    Unprovoked     NaN
# 6143  Reported 15-Mar-1897  1897    Unprovoked     NaN
# 6167  Reported 13-Jun-1895  1895    Unprovoked     NaN
# 6273           30-Jul-1887  1887  Sea Disaster     NaN
# 6302  Reported 16-Apr-1885  1885    Unprovoked     NaN
# 6340  Reported 16-Aug-1881  1881    Unprovoked     NaN
# 6342           25-Jul-1881  1881    Unprovoked     NaN
# 6371           13-Oct-1878  1878    Unprovoked     NaN
# 6417  Reported 15-Jun-1874  1874    Unprovoked     NaN
# 6452           10-Apr-1869  1869       Invalid     NaN
# 6528  Reported 20-Nov-1856  1856    Unprovoked     NaN
# 6533           28-Jul-1855  1855    Unprovoked     NaN
# 6624  Reported 22-Apr-1830  1830    Unprovoked     NaN
# 6651           01-Mar-1811  1811    Unprovoked     NaN
# 6663  Reported 18-Dec-1801  1801      Provoked     NaN
# 6665  Reported May-28-1797  1797    Unprovoked     NaN
# 6669           05-Jul-1787  1787    Unprovoked     NaN
# 6687           17-Dec-1742  1742    Unprovoked     NaN
# 6697         Reported 1638  1638    Unprovoked     NaN
# 6703                  1555  1555    Unprovoked     NaN
# 6709          Ca. 77  A.D.  0077    Unprovoked     NaN
# 6711          Ca. 214 B.C.  0000    Unprovoked     NaN
# 6737           Before 2011  0000      Provoked     NaN
# 6744           Before 2012  0000    Unprovoked     NaN
# 6797             1941-1945  0000  Sea Disaster     NaN
#
#                                                Area  \
# 572                                             NaN
# 1038                                            NaN
# 3474                                English Channel
# 3904                                            NaN
# 3913                                  Caribbean Sea
# 3914                                            NaN
# 3921                                            NaN
# 3925                                            NaN
# 3951                                            NaN
# 4131                                            NaN
# 4187                                            NaN
# 4544              Between Timor & Darwin, Australia
# 4757             Near the Andaman & Nicobar Islands
# 4792                   Between Comores & Madagascar
# 5027                                  Caribbean Sea
# 5168                                            NaN
# 5229                       Off South American coast
# 5241  300 miles east of St. Thomas (Virgin Islands)
# 5255                                            NaN
# 5258                                            NaN
# 5440                                            NaN
# 5549                    French Southern Territories
# 5589                                            NaN
# 5955                                            NaN
# 6116                                            NaN
# 6117                                            NaN
# 6143                              Mediterranean Sea
# 6167                                            NaN
# 6273                             Gulf of California
# 6302                                            NaN
# 6340                                  Western Banks
# 6342                                            NaN
# 6371                                            NaN
# 6417                                            NaN
# 6452                                            NaN
# 6528                                            NaN
# 6533                                            NaN
# 6624                                            NaN
# 6651                                            NaN
# 6663                                            NaN
# 6665                                            NaN
# 6669                                      St Helena
# 6687                                            NaN
# 6697                                            NaN
# 6703                                            NaN
# 6709                                     Ionian Sea
# 6711                                     Ionian Sea
# 6737                                            NaN
# 6744                                            NaN
# 6797                                            NaN
#
#                                        Location  \
# 572                                         NaN
# 1038                                        NaN
# 3474                                        NaN
# 3904                                        NaN
# 3913                  Between St. Kitts & Nevis
# 3914                                        NaN
# 3921                                        NaN
# 3925                                        NaN
# 3951                                        NaN
# 4131                             Florida Strait
# 4187                                        NaN
# 4544                                        NaN
# 4757                                        NaN
# 4792                                Geyser Bank
# 5027                Between  Cuba  & Costa Rica
# 5168                225 miles east of Hong Kong
# 5229                                        NaN
# 5241                                        NaN
# 5255                                        NaN
# 5258                                        NaN
# 5440                                        NaN
# 5549                             Île Saint-Paul
# 5589                                        NaN
# 5955                           Near the equator
# 6116                                        NaN
# 6117                                        NaN
# 6143                                        NaN
# 6167                                        NaN
# 6273                                        NaN
# 6302                                        NaN
# 6340                                        NaN
# 6342                                 Santa Cruz
# 6371                                        NaN
# 6417                                        NaN
# 6452                                        NaN
# 6528                                        NaN
# 6533                                        NaN
# 6624                                        NaN
# 6651                                        NaN
# 6663                                        NaN
# 6665                                        NaN
# 6669                              Landing Place
# 6687                               Carlisle Bay
# 6697                                        NaN
# 6703                                        NaN
# 6709                                        NaN
# 6711                                        NaN
# 6737                                        NaN
# 6744  In a river feeding into the Bay of Bengal
# 6797                                        NaN
#
#                                                Activity  \
# 572                                             Surfing
# 1038                                       Sea disaster
# 3474                                           Swimming
# 3904                                                NaN
# 3913        Sea Disaster Sinking of ferryboat Christina
# 3914                                                NaN
# 3921                                         Freediving
# 3925                                             Wading
# 3951                                                NaN
# 4131                           The boat Caribou II sank
# 4187                                       Spearfishing
# 4544  Portuguese Airliner with 9 people aboard went ...
# 4757                              Climbing back on ship
# 4792                                          Shipwreck
# 5027     Sea Disaster, sinking of the motorship Wingate
# 5168  Japanese POW ship Arisan Maru with 1800 Americ...
# 5229  Dutch merchant ship Zaandam torpedoed  by the ...
# 5241  On life raft tethered to lifeboat. A seaman pu...
# 5255  Jumped overboard from torpedoed Panamanian fre...
# 5258  Days before the surrender of Singapore, the 3 ...
# 5440                                             Diving
# 5549                             Fishing, boat capsized
# 5589                                                NaN
# 5955                                  Jumped overboard
# 6116                                             Diving
# 6117                                             Diving
# 6143                                           Swimming
# 6167                                             Diving
# 6273              Sea disaster, wreck of the sloop Sara
# 6302                                           Swimming
# 6340  Floating, holding onto an oar after dory capsized
# 6342                                            Bathing
# 6371       Jumped overboard after murdering 2 shipmates
# 6417                              Salvaging a shipwreck
# 6452                                     Fell overboard
# 6528                                           Swimming
# 6533                                            Bathing
# 6624                                                NaN
# 6651                                     Fell overboard
# 6663                    Standing on landed shark's tail
# 6665                                  Dropped overboard
# 6669                                           Swimming
# 6687                                           Swimming
# 6697                                                NaN
# 6703                                           Swimming
# 6709                                      Sponge diving
# 6711                              Ascending from a dive
# 6737                                                NaN
# 6744                                     Netting shrimp
# 6797         A group of survivors on a raft for 17-days
#
#                                                    Name Sex   Age  \
# 572                                       Timur Yunusov    M   24
# 1038                                     Cuban refugees    M  NaN
# 3474                 Padma Shri Taranath Narayan Shenoy    M  NaN
# 3904                                      Heinz Plotsky    M  NaN
# 3913                                                NaN  NaN  NaN
# 3914                                               male    M  NaN
# 3921                                      Lionel Jarvis    M  NaN
# 3925                                  Sally Anne Irvine    F    8
# 3951                                      Rodney Hughes    M   25
# 4131                                  Mario Castellanos    M   39
# 4187                                  Giancarlo Griffon    M   24
# 4544                                                NaN  NaN  NaN
# 4757                                               male    M  NaN
# 4792   Captain Eric Hunt, the cook & a French passenger    M  NaN
# 5027                Albert Battles, James Dean & 4 crew    M  NaN
# 5168                                                NaN    M  NaN
# 5229                                                NaN    M  NaN
# 5241                                               male    M  NaN
# 5255                                               male    M  NaN
# 5258  Bombardier J. Hall, Private Green of the Sherw...    M  NaN
# 5440                                  Pearl Purdy Scott    F  NaN
# 5549                                          Quillezic    M  NaN
# 5589                                      Thomas Duggan    M   20
# 5955                                      Thomas Butler    M   36
# 6116                                           Halletts    M  NaN
# 6117                                               male    M  NaN
# 6143                                               male    M  NaN
# 6167                                              Marsh    M  NaN
# 6273                                            2 males    M  NaN
# 6302                                            2 males    M  NaN
# 6340                                    George Sedgwick    M   20
# 6342                                      Father Hudson    M  NaN
# 6371                                        Sherrington    M  NaN
# 6417                                               male    M  NaN
# 6452                                Christian Frederick    M  NaN
# 6528                                 Cornelius Conhlren    M   22
# 6533       a young boy, one of the crew of the Post Boy    M  NaN
# 6624                                               Jose    M  NaN
# 6651                                        John Walker    M  NaN
# 6663                                   Stephen Pettigew    N  NaN
# 6665                                              child  NaN  NaN
# 6669                             Private Isaac Hicksled    M  NaN
# 6687                                 2 impressed seamen    M  NaN
# 6697                                            sailors    M  NaN
# 6703                                               male    M  NaN
# 6709                                              males    M  NaN
# 6711                            Tharsys, a sponge diver    M  NaN
# 6737                                     Phillip Peters    M  NaN
# 6744                                     Sametra Mestri    F  NaN
# 6797                                                 C.  NaN  NaN
#
#                                                  Injury Fatal (Y/N)  \
# 572                             Puncture wounds to feet           N
# 1038     Shark involvement prior to death not confirmed         NaN
# 3474                                    Left leg bitten           N
# 3904                                 Extensive injuries           N
# 3913  Sharks scavenged on bodies, but no record of t...         NaN
# 3914                              Finger or toe severed           N
# 3921  Arm abraded & lacerated. Recorded as PROVOKED ...           N
# 3925                           Lacerations to lower leg           N
# 3951                                       Am lacerated           N
# 4131                                           Survived           N
# 4187  Disappeared, probable drowning but sharks in a...         NaN
# 4544  As searchers approached wreckage, sharks circl...           N
# 4757                                              FATAL           Y
# 4792                                              FATAL           Y
# 5027                    Fatal or drowning or scavenging           Y
# 5168  Most of the men drowned & some were taken by s...           Y
# 5229                                              FATAL           Y
# 5241                                  Forearm lacerated           N
# 5255                                              FATAL           Y
# 5258  No injury to occupants. Sharks continually fol...           N
# 5440                             Laceration to left leg           N
# 5549                                              FATAL           Y
# 5589                                              FATAL           Y
# 5955                                              FATAL         NaN
# 6116  Lacerations to hand from shark trapped inside ...           N
# 6117                             Lacerations to fingers           N
# 6143                                              FATAL           Y
# 6167                                 Right hand severed           N
# 6273                                              FATAL           Y
# 6302                                              FATAL           Y
# 6340                                              FATAL           Y
# 6342                                           Survived           N
# 6371                                              FATAL           Y
# 6417                                        Heel bitten           N
# 6452                                              FATAL         NaN
# 6528                                              FATAL           Y
# 6533                                              FATAL           Y
# 6624                                              FATAL           Y
# 6651                                              FATAL           Y
# 6663                           FATAL, PROVOKED INCIDENT           Y
# 6665                                              FATAL           Y
# 6669                                              FATAL           Y
# 6687                                              FATAL           Y
# 6697                                                NaN     UNKNOWN
# 6703                                                NaN     UNKNOWN
# 6709                                              FATAL           Y
# 6711                      FATAL, shark/s bit him in two           Y
# 6737        Bitten by captive sharks PROVOKED INCIDENTS           N
# 6744                                       Hand severed           N
# 6797  FATAL, shark leapt into raft and bit the man w...           Y
#
#                 Time                                           Species   \
# 572              NaN                                                NaN
# 1038             NaN                    Shark involvement not confirmed
# 3474             NaN                                                NaN
# 3904             NaN                                                NaN
# 3913       Afternoon  Shark involvement prior to death was not confi...
# 3914           Night                                         Mako shark
# 3921             NaN                                   Wobbegong shark
# 3925             NaN                                       Carpet shark
# 3951             NaN                                                NaN
# 4131             NaN                                                NaN
# 4187           11h00  Shark involvement prior to death was not confi...
# 4544             NaN                                                NaN
# 4757            P.M.                                         Blue shark
# 4792             NaN                                                NaN
# 5027             NaN                    Shark involvement not confirmed
# 5168          >17h30                                                NaN
# 5229             NaN                                                NaN
# 5241             NaN                                                NaN
# 5255             NaN                                                NaN
# 5258             NaN                                                NaN
# 5440             NaN                                                NaN
# 5549             NaN                                                NaN
# 5589             NaN                                                NaN
# 5955             NaN                                       Questionable
# 6116             NaN                                                NaN
# 6117             NaN                                                NaN
# 6143             NaN                                                NaN
# 6167             NaN                                                NaN
# 6273             NaN                                                NaN
# 6302             NaN                                                NaN
# 6340             NaN                                                NaN
# 6342             NaN                                                NaN
# 6371             NaN                                                NaN
# 6417             NaN                                                NaN
# 6452             NaN       Shark involvement prior to death unconfirmed
# 6528             NaN                                                NaN
# 6533             NaN                                                NaN
# 6624           Night                                                NaN
# 6651             NaN                                                NaN
# 6663             NaN                                          12' shark
# 6665             NaN                                                NaN
# 6669             NaN                                                NaN
# 6687             NaN                                                NaN
# 6697             NaN                                                NaN
# 6703             NaN                                                NaN
# 6709             NaN                                                NaN
# 6711             NaN                                                NaN
# 6737             NaN                                                NaN
# 6744             NaN                                                NaN
# 6797  Late afternoon                                   1.2 m [4'] shark
#
#                                  Investigator or Source
# 572                                           Instagram
# 1038                       Associated Press, 11/27/2014
# 3474                           Times of India, 2/5/2012
# 3904              H.D. Baldridge (1994), SAF Case #1645
# 3913                        Rome News Tribune, 8/3/1970
# 3914              H.D. Baldridge (1994), SAF Case #1628
# 3921              H.D. Baldridge (1994), SAF Case #1616
# 3925               H.D. Baldridge (1994) SAF Case #1626
# 3951               H.D. Baldridge (1994) SAF Case #1602
# 4131                     Lodi News Sentinel, 10/30/1965
# 4187                                     C. Moore. GSAF
# 4544                       V.M. Coppleson (1962), p.260
# 4757                                          M. Hosina
# 4792                                       dinofish.com
# 5027                           Canberra Times, 1/6/1950
# 5168                                internet (multiple)
# 5229      M.  Murphy; V.M. Coppleson (1962), pp.207-208
# 5241                       V.M. Coppleson (1962), p.258
# 5255                       V.M. Coppleson (1962), p.258
# 5258                       V.M. Coppleson (1962), p.206
# 5440                        Port Arthur News, 4/12/1935
# 5549                       Los Angeles Times, 4/27/1931
# 5589                                 The Age, 12/9/1929
# 5955                                    Star, 3/18/1909
# 6116       Lincoln Evening News & Daily Call, 9/19/1898
# 6117       Lincoln Evening News & Daily Call, 9/19/1898
# 6143                      Daily Northwestern, 5/15/1897
# 6167                              Lima Times, 6/13/1895
# 6273                 Austin Weekly Statesman, 8/11/1887
# 6302                       Gleaner (Jamaica), 4/16/1885
# 6340                Lewiston Evening Journal, 8/16/1881
# 6342                    Grey River Argus,10/3/1881, p.2
# 6371  The Maitland Mercury & Hunter River General Ad...
# 6417                    Daily Southern Cross, 6/15/1874
# 6452  Nelson Examiner & New Zealand Chronicle, 4/24/...
# 6528          Pacific Commercial Advertiser, 11/20/1856
# 6533                        Maitland Mercury, 8/25/1855
# 6624      The Torchlight & Public Advertiser, 4/22/1830
# 6651                         Journal of Captain Marryat
# 6663                       The Evening Post, 12/18/1801
# 6665                             The Observer 5/28/1797
# 6669  H.R. Janisch (1885), Extracts from the St. Hel...
# 6687                                     C. Moore, GSAF
# 6697                                 Sir Thomas Herbert
# 6703                                       Olaus Magnus
# 6709  Perils mentioned by Pliny the Elder (23 A.D. t...
# 6711  Reported by Greek poet, Leonidas of Tarentum (...
# 6737                    Watertown Daily Times, 7/8/2011
# 6744                    National Georgraphic Television
# 6797         G.A. Llano in Airmen Against the Sea, p.69

# %%
#COLUNA COUNTRY - Alterando valores NaN (part2: Dropando valores que são impossíveis completar o país)
index_countries_nan = sharkattack_main.loc[(sharkattack_main['Country'].isnull()) & (sharkattack_main['Location'].isnull()) & (sharkattack_main['Area'].isnull())].index
sharkattack_main = sharkattack_main.drop(index_countries_nan,axis=0).reset_index()

# %%
sharkattack_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6811 entries, 0 to 6810
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   index                   6811 non-null   int64
#  1   Date                    6811 non-null   object
#  2   Year                    6809 non-null   object
#  3   Type                    6791 non-null   object
#  4   Country                 6790 non-null   object
#  5   Area                    6362 non-null   object
#  6   Location                6279 non-null   object
#  7   Activity                6235 non-null   object
#  8   Name                    6592 non-null   object
#  9   Sex                     6236 non-null   object
#  10  Age                     3863 non-null   object
#  11  Injury                  6778 non-null   object
#  12  Fatal (Y/N)             6256 non-null   object
#  13  Time                    3335 non-null   object
#  14  Species                 3749 non-null   object
#  15  Investigator or Source  6792 non-null   object
# dtypes: int64(1), object(15)
# memory usage: 851.5+ KB

# %%
#COLUNA COUNTRY - Alterando valores NaN (part3: Alterando valores que são possíveis completar o país)
sharkattack_main.loc[(sharkattack_main['Country'].isnull()) & (~sharkattack_main['Location'].isnull()|~sharkattack_main['Area'].isnull())]
# Out:
#       index                  Date  Year          Type Country  \
# 3472   3474              Ca. 1983  1983    Unprovoked     NaN
# 3910   3913           02-Aug-1970  1970       Invalid     NaN
# 4124   4131           21-Oct-1965  1965    Unprovoked     NaN
# 4536   4544           26-Jan-1960  1960  Sea Disaster     NaN
# 4749   4757           13-Sep-1956  1956    Unprovoked     NaN
# 4784   4792                  1956  1956  Sea Disaster     NaN
# 5019   5027              Dec-1949  1949  Sea Disaster     NaN
# 5160   5168           24-Oct-1944  1944  Sea Disaster     NaN
# 5221   5229              Nov-1942  1942  Sea Disaster     NaN
# 5233   5241              Jun-1942  1942    Unprovoked     NaN
# 5538   5549  Reported 27-Apr-1931  1931    Unprovoked     NaN
# 5943   5955           17-Jan-1909  1909       Invalid     NaN
# 6129   6143  Reported 15-Mar-1897  1897    Unprovoked     NaN
# 6258   6273           30-Jul-1887  1887  Sea Disaster     NaN
# 6324   6340  Reported 16-Aug-1881  1881    Unprovoked     NaN
# 6326   6342           25-Jul-1881  1881    Unprovoked     NaN
# 6644   6669           05-Jul-1787  1787    Unprovoked     NaN
# 6662   6687           17-Dec-1742  1742    Unprovoked     NaN
# 6682   6709          Ca. 77  A.D.  0077    Unprovoked     NaN
# 6684   6711          Ca. 214 B.C.  0000    Unprovoked     NaN
# 6716   6744           Before 2012  0000    Unprovoked     NaN
#
#                                                Area  \
# 3472                                English Channel
# 3910                                  Caribbean Sea
# 4124                                            NaN
# 4536              Between Timor & Darwin, Australia
# 4749             Near the Andaman & Nicobar Islands
# 4784                   Between Comores & Madagascar
# 5019                                  Caribbean Sea
# 5160                                            NaN
# 5221                       Off South American coast
# 5233  300 miles east of St. Thomas (Virgin Islands)
# 5538                    French Southern Territories
# 5943                                            NaN
# 6129                              Mediterranean Sea
# 6258                             Gulf of California
# 6324                                  Western Banks
# 6326                                            NaN
# 6644                                      St Helena
# 6662                                            NaN
# 6682                                     Ionian Sea
# 6684                                     Ionian Sea
# 6716                                            NaN
#
#                                        Location  \
# 3472                                        NaN
# 3910                  Between St. Kitts & Nevis
# 4124                             Florida Strait
# 4536                                        NaN
# 4749                                        NaN
# 4784                                Geyser Bank
# 5019                Between  Cuba  & Costa Rica
# 5160                225 miles east of Hong Kong
# 5221                                        NaN
# 5233                                        NaN
# 5538                             Île Saint-Paul
# 5943                           Near the equator
# 6129                                        NaN
# 6258                                        NaN
# 6324                                        NaN
# 6326                                 Santa Cruz
# 6644                              Landing Place
# 6662                               Carlisle Bay
# 6682                                        NaN
# 6684                                        NaN
# 6716  In a river feeding into the Bay of Bengal
#
#                                                Activity  \
# 3472                                           Swimming
# 3910        Sea Disaster Sinking of ferryboat Christina
# 4124                           The boat Caribou II sank
# 4536  Portuguese Airliner with 9 people aboard went ...
# 4749                              Climbing back on ship
# 4784                                          Shipwreck
# 5019     Sea Disaster, sinking of the motorship Wingate
# 5160  Japanese POW ship Arisan Maru with 1800 Americ...
# 5221  Dutch merchant ship Zaandam torpedoed  by the ...
# 5233  On life raft tethered to lifeboat. A seaman pu...
# 5538                             Fishing, boat capsized
# 5943                                  Jumped overboard
# 6129                                           Swimming
# 6258              Sea disaster, wreck of the sloop Sara
# 6324  Floating, holding onto an oar after dory capsized
# 6326                                            Bathing
# 6644                                           Swimming
# 6662                                           Swimming
# 6682                                      Sponge diving
# 6684                              Ascending from a dive
# 6716                                     Netting shrimp
#
#                                                   Name Sex   Age  \
# 3472                Padma Shri Taranath Narayan Shenoy    M  NaN
# 3910                                               NaN  NaN  NaN
# 4124                                 Mario Castellanos    M   39
# 4536                                               NaN  NaN  NaN
# 4749                                              male    M  NaN
# 4784  Captain Eric Hunt, the cook & a French passenger    M  NaN
# 5019               Albert Battles, James Dean & 4 crew    M  NaN
# 5160                                               NaN    M  NaN
# 5221                                               NaN    M  NaN
# 5233                                              male    M  NaN
# 5538                                         Quillezic    M  NaN
# 5943                                     Thomas Butler    M   36
# 6129                                              male    M  NaN
# 6258                                           2 males    M  NaN
# 6324                                   George Sedgwick    M   20
# 6326                                     Father Hudson    M  NaN
# 6644                            Private Isaac Hicksled    M  NaN
# 6662                                2 impressed seamen    M  NaN
# 6682                                             males    M  NaN
# 6684                           Tharsys, a sponge diver    M  NaN
# 6716                                    Sametra Mestri    F  NaN
#
#                                                  Injury Fatal (Y/N)  \
# 3472                                    Left leg bitten           N
# 3910  Sharks scavenged on bodies, but no record of t...         NaN
# 4124                                           Survived           N
# 4536  As searchers approached wreckage, sharks circl...           N
# 4749                                              FATAL           Y
# 4784                                              FATAL           Y
# 5019                    Fatal or drowning or scavenging           Y
# 5160  Most of the men drowned & some were taken by s...           Y
# 5221                                              FATAL           Y
# 5233                                  Forearm lacerated           N
# 5538                                              FATAL           Y
# 5943                                              FATAL         NaN
# 6129                                              FATAL           Y
# 6258                                              FATAL           Y
# 6324                                              FATAL           Y
# 6326                                           Survived           N
# 6644                                              FATAL           Y
# 6662                                              FATAL           Y
# 6682                                              FATAL           Y
# 6684                      FATAL, shark/s bit him in two           Y
# 6716                                       Hand severed           N
#
#            Time                                           Species   \
# 3472        NaN                                                NaN
# 3910  Afternoon  Shark involvement prior to death was not confi...
# 4124        NaN                                                NaN
# 4536        NaN                                                NaN
# 4749       P.M.                                         Blue shark
# 4784        NaN                                                NaN
# 5019        NaN                    Shark involvement not confirmed
# 5160     >17h30                                                NaN
# 5221        NaN                                                NaN
# 5233        NaN                                                NaN
# 5538        NaN                                                NaN
# 5943        NaN                                       Questionable
# 6129        NaN                                                NaN
# 6258        NaN                                                NaN
# 6324        NaN                                                NaN
# 6326        NaN                                                NaN
# 6644        NaN                                                NaN
# 6662        NaN                                                NaN
# 6682        NaN                                                NaN
# 6684        NaN                                                NaN
# 6716        NaN                                                NaN
#
#                                  Investigator or Source
# 3472                           Times of India, 2/5/2012
# 3910                        Rome News Tribune, 8/3/1970
# 4124                     Lodi News Sentinel, 10/30/1965
# 4536                       V.M. Coppleson (1962), p.260
# 4749                                          M. Hosina
# 4784                                       dinofish.com
# 5019                           Canberra Times, 1/6/1950
# 5160                                internet (multiple)
# 5221      M.  Murphy; V.M. Coppleson (1962), pp.207-208
# 5233                       V.M. Coppleson (1962), p.258
# 5538                       Los Angeles Times, 4/27/1931
# 5943                                    Star, 3/18/1909
# 6129                      Daily Northwestern, 5/15/1897
# 6258                 Austin Weekly Statesman, 8/11/1887
# 6324                Lewiston Evening Journal, 8/16/1881
# 6326                    Grey River Argus,10/3/1881, p.2
# 6644  H.R. Janisch (1885), Extracts from the St. Hel...
# 6662                                     C. Moore, GSAF
# 6682  Perils mentioned by Pliny the Elder (23 A.D. t...
# 6684  Reported by Greek poet, Leonidas of Tarentum (...
# 6716                    National Georgraphic Television

# %%
#COLUNA COUNTRY - Alterando valores NaN (part3.1: Alterando valores que são possíveis completar o país)
sharkattack_main.loc[sharkattack_main["Area"] == "St Helena", "Country"] = "ST HELENA, BRITISH OVERSEAS TERRITORY"
sharkattack_main.loc[sharkattack_main["Location"] == "Île Saint-Paul", "Country"] = "ÎLE SAINT-PAUL, FRENCH OVERSEAS TERRITORY"

# %%
#COLUNA COUNTRY - Ajustando valores(part 3.2: Alterando alguns países)
sharkattack_main.loc[sharkattack_main["Country"] == "JA MAICA", "Country"] = "JAMAICA"
sharkattack_main.loc[sharkattack_main["Country"] == "OKINAWA", "Country"] = "JAPAN"
sharkattack_main.loc[sharkattack_main["Country"] == "UNITED ARAB EMIRATES (UAE)", "Country"] = "UNITED ARAB EMIRATES"

# %%
#COLUNA COUNTRY - Alterando valores NaN (part3.2: Alterando valores que não são possíveis completar o país)
sharkattack_main["Update Countries"] = sharkattack_main['Country'].map(lambda country: "IN BETWEEN COUNTRIES OR HIGH SEA" if country != country else country)
sharkattack_main = sharkattack_main.loc[:,['index', 'Date', 'Year', 'Type', 'Country', 'Update Countries', 'Area', 'Location','Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ', 'Investigator or Source']]
sharkattack_main
# Out:
#       index         Date  Year        Type             Country  \
# 0         0  25-Mar-2023  2023  Unprovoked                 USA
# 1         1  22-Mar-2023  2023  Unprovoked           AUSTRALIA
# 2         2  19-Mar-2023  2023  Unprovoked                 USA
# 3         3  17-Mar-2023  2023  Unprovoked              MEXICO
# 4         4  16-Mar-2023  2023  Unprovoked           AUSTRALIA
# ...     ...          ...   ...         ...                 ...
# 6806   6835  Before 1903  0000  Unprovoked           AUSTRALIA
# 6807   6836  Before 1903  0000  Unprovoked           AUSTRALIA
# 6808   6837    1900-1905  0000  Unprovoked                 USA
# 6809   6838    1883-1889  0000  Unprovoked              PANAMA
# 6810   6839    1845-1853  0000  Unprovoked  CEYLON (SRI LANKA)
#
#         Update Countries               Area  \
# 0                    USA            Florida
# 1              AUSTRALIA  Western Australia
# 2                    USA             Hawaii
# 3                 MEXICO       Quintana Roo
# 4              AUSTRALIA  Western Australia
# ...                  ...                ...
# 6806           AUSTRALIA  Western Australia
# 6807           AUSTRALIA  Western Australia
# 6808                 USA     North Carolina
# 6809              PANAMA                NaN
# 6810  CEYLON (SRI LANKA)   Eastern Province
#
#                                         Location      Activity  \
# 0     Blue Fish Channel, Key West, Monroe County  Kite-Surfing
# 1                                   Delta Island        Wading
# 2                                Anaehoomalu Bay      Swimming
# 3                                         Cancún      Swimming
# 4                                 Cheynes Beach     Surf-sking
# ...                                          ...           ...
# 6806                                 Roebuck Bay        Diving
# 6807                                         NaN  Pearl diving
# 6808                              Ocracoke Inlet      Swimming
# 6809                        Panama Bay 8ºN, 79ºW           NaN
# 6810         Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   Age  \
# 0      Kevin  Carlton Scott    M   67
# 1               Adam Norton    M  30s
# 2                      male    M   60
# 3             Dillon Armijo    M   10
# 4                    female    F  NaN
# ...                     ...  ...  ...
# 6806                   male    M  NaN
# 6807                  Ahmun    M  NaN
# 6808  Coast Guard personnel    M  NaN
# 6809        Jules Patterson    M  NaN
# 6810                   male    M   15
#
#                                                  Injury Fatal (Y/N)   Time  \
# 0                              Lacertions to right calf           N  14h00
# 1                       Lower left leg and foot injured           N  18h00
# 2                              Left hand and  left leg.           N  12h30
# 3                           Significant  injury to leg            N    NaN
# 4                                                   NaN           N  08h00
# ...                                                 ...         ...    ...
# 6806                                              FATAL           Y    NaN
# 6807                                              FATAL           Y    NaN
# 6808                                              FATAL           Y    NaN
# 6809                                              FATAL           Y    NaN
# 6810  FATAL. "Shark bit him in half, carrying away t...           Y    NaN
#
#             Species                  Investigator or Source
# 0                NaN                  Yahoo News, 3/28/2023
# 1                NaN                        A. Currie, GSAF
# 2                NaN                       Khon2, 3/19/2023
# 3                NaN                     Denver7, 3/29/2023
# 4     5m to 6m shark                         B. Myatt, GSAF
# ...              ...                                    ...
# 6806             NaN       H. Taunton; N. Bartlett,  p. 234
# 6807             NaN  H. Taunton; N. Bartlett,  pp. 233-234
# 6808             NaN   F. Schwartz, p.23; C. Creswell, GSAF
# 6809             NaN                    The Sun, 10/20/1938
# 6810             NaN                             S.W. Baker
#
# [6811 rows x 17 columns]

# %%
#COLUNA COUNTRY - Ajustando valores (part1: Analisando os valores únicos de Country)
len(list(sharkattack_main['Update Countries'].unique()))
# Out:
# 221

# %%
#COLUNA COUNTRY - Ajustando valores (part2: Deixando todos os valores em um mesmo padrão)
sharkattack_main['Update Countries'] = sharkattack_main['Update Countries'].str.upper()
sharkattack_main['Update Countries'] = sharkattack_main['Update Countries'].str.strip()
sharkattack_main['Update Countries'] = sharkattack_main['Update Countries'].str.replace(r'\?$',"", regex=True)

# %%
#COLUNA COUNTRY - Ajustando valores  (part3: definindo quais são os países únicos)
shark_countries = list(sharkattack_main['Update Countries'].unique())

# %%
#COLUNA COUNTRY - Ajustando valores  (part4: analisando se todos países estão com grafias certas)
countries_list = read_from_gsheets('https://docs.google.com/spreadsheets/d/1m4jcr2736SL20HbEVeWPkAap1FVOAvGwF5bkgrAO8vs/edit?usp=sharing')
countries_list = list(countries_list["COUNTRY"])

unique_countries = list(set(shark_countries) - set(countries_list))
unique_countries
# Out:
# ['COAST OF AFRICA',
#  'SOLOMON ISLANDS / VANUATU',
#  'BRITISH ISLES',
#  'ITALY / CROATIA',
#  'BRITISH OVERSEAS TERRITORY',
#  'EQUATORIAL GUINEA / CAMEROON',
#  'ANDAMAN ISLANDS',
#  'PALESTINIAN TERRITORIES',
#  'RED SEA',
#  'BRITISH NEW GUINEA',
#  'SOUTH CHINA SEA',
#  'BRITISH WEST INDIES',
#  'COLUMBIA',
#  'INDIAN OCEAN',
#  'SOUTH PACIFIC OCEAN',
#  'WESTERN SAMOA',
#  'JAVA',
#  'ANDAMAN / NICOBAR ISLANDAS',
#  'NEW GUINEA',
#  'TOBAGO',
#  'CEYLON (SRI LANKA)',
#  'OCEAN',
#  'GRAND CAYMAN',
#  'MID-PACIFC OCEAN',
#  'ST HELENA, BRITISH OVERSEAS TERRITORY',
#  'TRINIDAD & TOBAGO',
#  'ASIA',
#  'NORTHERN ARABIAN SEA',
#  'SAN DOMINGO',
#  'PACIFIC OCEAN',
#  'USA',
#  'NEW BRITAIN',
#  'ST. MAARTIN',
#  'CARIBBEAN SEA',
#  'PERSIAN GULF',
#  'ST KITTS / NEVIS',
#  'MALDIVE ISLANDS',
#  'AZORES',
#  'ENGLAND',
#  'MID ATLANTIC OCEAN',
#  'CRETE',
#  'NORTH ATLANTIC OCEAN',
#  'ATLANTIC OCEAN',
#  'IRAN / IRAQ',
#  'AFRICA',
#  'BAHREIN',
#  'ST. MARTIN',
#  'DIEGO GARCIA',
#  'WEST INDIES',
#  'REUNION ISLAND',
#  'BETWEEN PORTUGAL & INDIA',
#  'FEDERATED STATES OF MICRONESIA',
#  'MEDITERRANEAN SEA',
#  'EGYPT / ISRAEL',
#  'RED SEA / INDIAN OCEAN',
#  'THE BALKANS',
#  'BURMA',
#  'SOUTH ATLANTIC OCEAN',
#  'ÎLE SAINT-PAUL, FRENCH OVERSEAS TERRITORY',
#  'NORTH PACIFIC OCEAN',
#  'ST MARTIN',
#  'SOUTHWEST PACIFIC OCEAN',
#  'CENTRAL PACIFIC',
#  'BAY OF BENGAL',
#  'ANTIGUA',
#  'IN BETWEEN COUNTRIES OR HIGH SEA',
#  'TURKS & CAICOS',
#  'JOHNSTON ISLAND',
#  'ADMIRALTY ISLANDS',
#  'CEYLON',
#  'SCOTLAND',
#  'NETHERLANDS ANTILLES',
#  'NEVIS',
#  'TASMAN SEA',
#  'ROATAN',
#  'NORTH SEA',
#  'GULF OF ADEN',
#  'KOREA']

# %%
#COLUNA COUNTRY - Ajustando valores(part 5: Descobrindo se há uma coluna com "sea" ou "ocean" ou "river" ou "between countries (/)" ou "gulf ou "Coast"
ocean_df = sharkattack_main.loc[sharkattack_main['Update Countries'].str.contains(r'SEA|OCEAN|RIVER|GULF|BETWEEN|COAST|/|CHANNEL|PACIFIC'),"Update Countries"]

sharkattack_main.loc[sharkattack_main['Update Countries'].isin(ocean_df), 'Update Countries'] = "IN BETWEEN COUNTRIES OR HIGH SEA"

len(sharkattack_main['Update Countries'].unique())
# Out:
# 169

# %%
#COLUNA COUNTRY - Ajustando valores(part 6: Analisando os novos valores únicos)

sharkattack_main['Update Countries'].unique()
# Out:
# array(['USA', 'AUSTRALIA', 'MEXICO', 'BRAZIL', 'SEYCHELLES',
#        'NEW CALEDONIA', 'ARGENTINA', 'FIJI', 'SOUTH AFRICA', 'BAHAMAS',
#        'ENGLAND', 'JAPAN', 'INDONESIA', 'EGYPT', 'JAMAICA', 'BELIZE',
#        'MALDIVES', 'FRENCH POLYNESIA', 'THAILAND', 'COLUMBIA',
#        'NEW ZEALAND', 'COSTA RICA', 'IN BETWEEN COUNTRIES OR HIGH SEA',
#        'CANADA', 'ECUADOR', 'JORDAN', 'ST MARTIN', 'SPAIN',
#        'PAPUA NEW GUINEA', 'REUNION ISLAND', 'ISRAEL', 'CHINA', 'SAMOA',
#        'IRELAND', 'ITALY', 'COLOMBIA', 'MALAYSIA', 'LIBYA', 'CUBA',
#        'MAURITIUS', 'SOLOMON ISLANDS', 'COMOROS', 'REUNION',
#        'UNITED KINGDOM', 'UNITED ARAB EMIRATES', 'PHILIPPINES',
#        'CAPE VERDE', 'DOMINICAN REPUBLIC', 'CAYMAN ISLANDS', 'ARUBA',
#        'MOZAMBIQUE', 'PUERTO RICO', 'GREECE', 'ST. MARTIN', 'FRANCE',
#        'TRINIDAD & TOBAGO', 'KIRIBATI', 'DIEGO GARCIA', 'TAIWAN',
#        'PALESTINIAN TERRITORIES', 'GUAM', 'NIGERIA', 'TONGA', 'SCOTLAND',
#        'CROATIA', 'SAUDI ARABIA', 'CHILE', 'ANTIGUA', 'KENYA', 'RUSSIA',
#        'TURKS & CAICOS', 'AZORES', 'SOUTH KOREA', 'MALTA', 'VIETNAM',
#        'MADAGASCAR', 'PANAMA', 'SOMALIA', 'NEVIS',
#        'BRITISH VIRGIN ISLANDS', 'NORWAY', 'SENEGAL', 'YEMEN',
#        'SIERRA LEONE', 'ST. MAARTIN', 'GRAND CAYMAN', 'LIBERIA',
#        'VANUATU', 'HONDURAS', 'VENEZUELA', 'SRI LANKA', 'URUGUAY',
#        'INDIA', 'MICRONESIA', 'TANZANIA', 'MARSHALL ISLANDS', 'HONG KONG',
#        'EL SALVADOR', 'ANGOLA', 'BERMUDA', 'MONTENEGRO', 'IRAN',
#        'TUNISIA', 'NAMIBIA', 'PORTUGAL', 'BANGLADESH', 'PALAU',
#        'WESTERN SAMOA', 'BRITISH ISLES', 'GRENADA', 'IRAQ', 'TURKEY',
#        'SINGAPORE', 'NEW BRITAIN', 'SUDAN', 'JOHNSTON ISLAND',
#        'NEW GUINEA', 'FEDERATED STATES OF MICRONESIA',
#        'ADMIRALTY ISLANDS', 'BRITISH WEST INDIES', 'NICARAGUA',
#        'MALDIVE ISLANDS', 'AMERICAN SAMOA', 'GABON', 'MAYOTTE',
#        'THE BALKANS', 'MARTINIQUE', 'GUATEMALA', 'NETHERLANDS ANTILLES',
#        'NORTHERN MARIANA ISLANDS', 'JAVA', 'BAY OF BENGAL', 'SLOVENIA',
#        'CURACAO', 'ICELAND', 'BARBADOS', 'MONACO', 'GUYANA', 'HAITI',
#        'SAN DOMINGO', 'KUWAIT', 'FALKLAND ISLANDS', 'CRETE', 'CYPRUS',
#        'WEST INDIES', 'BURMA', 'LEBANON', 'PARAGUAY',
#        'BRITISH NEW GUINEA', 'CEYLON', 'GEORGIA', 'SYRIA', 'TUVALU',
#        'GUINEA', 'ANDAMAN ISLANDS', 'COOK ISLANDS', 'TOBAGO', 'PERU',
#        'AFRICA', 'ALGERIA', 'GHANA', 'GREENLAND', 'SWEDEN', 'ROATAN',
#        'DJIBOUTI', 'BAHREIN', 'KOREA', 'ASIA', 'CEYLON (SRI LANKA)'],
#       dtype=object)

# %% [markdown]
# #*Coluna Date*

# %%
sharkattack_main.loc[:, 'Date'] = sharkattack_main['Date'].str.replace(r"(\d{2})-(\w{3})--?(\d{4})", r"\1-\2-\3")
pd.to_datetime(sharkattack_main['Date'], infer_datetime_format=True) 


#pd.to_datetime(sharkattack_main['Date'], infer_datetime_format=True, errors="coerce")
# Out:
# <ipython-input-279-2c6dc36ff2de>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   sharkattack_main.loc[:, 'Date'] = sharkattack_main['Date'].str.replace(r"(\d{2})-(\w{3})--?(\d{4})", r"\1-\2-\3")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-279-2c6dc36ff2de> in <cell line: 2>()
#       1 sharkattack_main.loc[:, 'Date'] = sharkattack_main['Date'].str.replace(r"(\d{2})-(\w{3})--?(\d{4})", r"\1-\2-\3")
# ----> 2 pd.to_datetime(sharkattack_main['Date'], infer_datetime_format=True,na=False)
#       3
#       4
#       5 #pd.to_datetime(sharkattack_main['Date'], infer_datetime_format=True, errors="coerce")
#
# TypeError: to_datetime() got an unexpected keyword argument 'na'

# %% [markdown]
# #*Coluna Estação (new)*

# %% [markdown]
# # Coluna Age

# %%
#COLUNA AGE - Investigando valores (part 1: Descobrindo os valores)
sharkattack_main['Age'].unique()
# Out:
# array(['67', '30s', '60', '10', nan, '15', '14', '6', '32', '59', '41',
#        '16', '8', '49', '34', '53', '30', '26', '68', '43', '50', '29',
#        '40', '51', '19', '38', '17', '31', '39', '58', '13', '33', '28',
#        '40s', '35', '62', 'teen', '20', '22', '56', 'Teen', '12', '50s',
#        '21', '42', '36', '18', '37', 'M', '9', '24', '11', '27', '57',
#        '25', '!6', '64', '!!', '47', '55', '7', '71', '48', '54', '75',
#        '45 and 15', '46', '61', '73', '52', '70', '23', '4', '63', '45',
#        '44', '28 & 22', '22, 57, 31', '60s', "20's", '65', '74', '9 & 60',
#        '20s', 'a minor', '69', '3', '82', '66', '72', '18 months', '77',
#        '28 & 26', '5', '86', '18 or 20', '12 or 13', '46 & 34',
#        '28, 23 & 30', 'Teens', '36 & 26', '8 or 10', '84', '\xa0 ', ' ',
#        '30 or 36', '6½', '21 & ?', '33 or 37', 'mid-30s', '23 & 20',
#        ' 30', '7      &    31', ' 28', '20?', "60's", '32 & 30',
#        '16 to 18', '87', 'Elderly', 'mid-20s', 'Ca. 33', '74 ', '45 ',
#        '21 or 26', '20 ', '>50', '18 to 22', 'adult', '9 & 12', '? & 19',
#        '9 months', '25 to 35', '23 & 26', '1', '(adult)', '33 & 37',
#        '25 or 28', '37, 67, 35, 27,  ? & 27', '21, 34,24 & 35', '30 & 32',
#        '50 & 30', '17 & 35', 'X', '"middle-age"', '13 or 18', '34 & 19',
#        '33 & 26', '2 to 3 months', 'MAKE LINE GREEN', ' 43', '81',
#        '"young"', '7 or 8', '78', '17 & 16', 'F', 'Both 11', '9 or 10',
#        'young', '36 & 23', '  ', 'A.M.', '?    &   14', '10 or 12',
#        '31 or 33', '2½', '13 or 14'], dtype=object)

# %%
#COLUNA AGE - Limpando as strings (part 1: transformando valores)

# %%
#COLUNA AGE - Limpando as strings (part 1: transformando valores)

#sharkattack_main["Update Countries"] = sharkattack_main['Country'].map(lambda country: "IN BETWEEN COUNTRIES OR HIGH SEA" if country != country else country)

# %%
#sharkattack_main['Age'].map(lambda age: "Adult" if age > 18 else "Child")

# %% [markdown]
# #Coluna Sex

# %%
#COLUNA SEX - Investigando valores (part 1: Descobrindo valores na coluna)
sharkattack_main['Sex '].value_counts()
# Out:
# M        5481
# F         748
# M           2
#  M          1
# lli         1
# M x 2       1
# N           1
# .           1
# Name: Sex , dtype: int64

# %%
#COLUNA SEX - Alterando valores possíveis (part 1: Alterando valores)
sharkattack_main['Sex '] = sharkattack_main['Sex '].str.strip()
sharkattack_main.loc[sharkattack_main["Sex "] == "lli", "Sex "] = "M"
sharkattack_main['Sex '] = sharkattack_main['Sex '].replace(".", np.nan)
sharkattack_main.loc[sharkattack_main["Sex "] == "M x 2", "Sex "] = "M"
sharkattack_main.loc[sharkattack_main["Sex "] == "N", "Sex "] = "M"

sharkattack_main['Sex '].value_counts()
# Out:
# M    5487
# F     748
# Name: Sex , dtype: int64

# %%
#COLUNA SEX - Alterando valores possíveis (part 2: Alterando valores Male/Men/Man)
regex_male = r'\bman\b|\bmen\b|\bmale\b|\bmales\b'
sharkattack_main.loc[(sharkattack_main['Sex '].isnull()) & (sharkattack_main['Name'].str.contains(regex_male, case=False, na=False)), "Sex "] = "M"

# %%
#COLUNA SEX - Alterando valores possíveis (part 2.1: Alterando valores Female/Woman/Women)
regex_female = r'\bwoman\b|\bwomen\b|\bfemale\b|\bfemales\b'
sharkattack_main.loc[(sharkattack_main['Sex '].isnull()) & (sharkattack_main['Name'].str.contains(regex_female, case=False, na=False)), "Sex "] = "F"

# %%
sharkattack_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6811 entries, 0 to 6810
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   index                   6811 non-null   int64
#  1   Date                    6811 non-null   object
#  2   Year                    6809 non-null   object
#  3   Type                    6791 non-null   object
#  4   Country                 6792 non-null   object
#  5   Update Countries        6811 non-null   object
#  6   Area                    6362 non-null   object
#  7   Location                6279 non-null   object
#  8   Activity                6235 non-null   object
#  9   Name                    6592 non-null   object
#  10  Sex                     6256 non-null   object
#  11  Age                     3863 non-null   object
#  12  Injury                  6778 non-null   object
#  13  Fatal (Y/N)             6256 non-null   object
#  14  Time                    3335 non-null   object
#  15  Species                 3749 non-null   object
#  16  Investigator or Source  6792 non-null   object
# dtypes: int64(1), object(16)
# memory usage: 904.7+ KB

# %%
#COLUNA SEX - Visualizando os NaN (part 1: Visualizando NaN para ter certeza que não é possível alterar)
sharkattack_main.loc[(sharkattack_main['Sex '].isnull()) & (sharkattack_main['Name'].isnull())]
# Out:
#       index                  Date  Year        Type           Country  \
# 54       54           19-Jul-2022  2022  Unprovoked               USA
# 78       78           27-May-2022  2022  Unprovoked         AUSTRALIA
# 82       82           07-May-2022  2022  Unprovoked  FRENCH POLYNESIA
# 215     215           22-Jan-2021  2021  Watercraft               USA
# 289     289           20-Jun-2020  2020  Unprovoked           BAHAMAS
# ...     ...                   ...   ...         ...               ...
# 6664   6689                  1733  1733     Invalid           ICELAND
# 6697   6724           Before 1934  0000  Unprovoked           URUGUAY
# 6708   6735           Before 2012  0000  Unprovoked             SPAIN
# 6747   6775  No date, Before 1963  0000  Unprovoked         SINGAPORE
# 6787   6816   Between 1918 & 1939  0000  Unprovoked           REUNION
#
#       Update Countries               Area  \
# 54                 USA            Florida
# 78           AUSTRALIA  Western Australia
# 82    FRENCH POLYNESIA          Bora Bora
# 215                USA            Florida
# 289            BAHAMAS             Exumas
# ...                ...                ...
# 6664           ICELAND        Bardestrand
# 6697           URUGUAY              Rocha
# 6708             SPAIN     Canary Islands
# 6747         SINGAPORE                NaN
# 6787           REUNION        Saint-Denis
#
#                                                Location     Activity Name  \
# 54                       Cape Canaveral, Brevard County          NaN  NaN
# 78                                            Yallingup      Surfing  NaN
# 82                                              To'opua          NaN  NaN
# 215                                       Off Tampa Bay      Fishing  NaN
# 289                               Pig Beach, Pig Island          NaN  NaN
# ...                                                 ...          ...  ...
# 6664                                       Talkknefiord          NaN  NaN
# 6697                              Isla Chica, La Paloma     Swimming  NaN
# 6708                                           Tenerife  Skin diving  NaN
# 6747  Keppel Harbor,  2 miles from Singapore city ce...     Swimming  NaN
# 6787                                          Barachois     Swimming  NaN
#
#      Sex   Age                                             Injury Fatal (Y/N)  \
# 54    NaN  NaN                                     minor injuries           N
# 78    NaN  NaN         Knocked off board by a  shark.   No injury           N
# 82    NaN  NaN                                        Hand bitten           N
# 215   NaN  NaN                             No injury to occupants           N
# 289   NaN  NaN                                                NaN           N
# ...   ...  ...                                                ...         ...
# 6664  NaN  NaN  Partial hominid remains recovered from shark, ...         NaN
# 6697  NaN  NaN                                        Foot bitten           N
# 6708  NaN  NaN                        Injury required 16 stitches           N
# 6747  NaN  NaN                                          Recovered           N
# 6787  NaN  NaN                                              FATAL           Y
#
#         Time                                      Species   \
# 54    10jh45               Shark involvement not confirmed
# 78       NaN                       Bronze whaler shark, 2m
# 82       NaN                                           NaN
# 215      NaN                                   White shark
# 289      NaN                                           NaN
# ...      ...                                           ...
# 6664     NaN  Shark involvement prior to death unconfirmed
# 6697     NaN                                           NaN
# 6708     NaN                                           NaN
# 6747     NaN                                           NaN
# 6787     NaN                                           NaN
#
#             Investigator or Source
# 54                 WESH, 7/20/2022
# 78            Perth Now, 5/27/2022
# 82    Franceinfo, 5/10/202232/2021
# 215           J. McCallister, GSAF
# 289            M. Michaelson, GSAF
# ...                            ...
# 6664                    E. Olafsen
# 6697               Di Candia, 2004
# 6708                C. Moore, GSAF
# 6747  V.M. Coppleson (1958), p.266
# 6787            G. Van Grevelynghe
#
# [153 rows x 17 columns]

# %%
#COLUNA SEX - Visualizando os NaN (part 2: Visualizando semi NaN para ter certeza que não é possível alterar)
sharkattack_main.loc[(sharkattack_main['Sex '].isnull()) & (~sharkattack_main['Name'].isnull())]
# Out:
#       index                  Date  Year          Type     Country  \
# 194     194           17-Apr-2021  2021      Provoked         USA
# 259     259           30-Aug-2020  2020    Watercraft   AUSTRALIA
# 274     274           29-Jul-2020  2020    Watercraft   AUSTRALIA
# 569     569  Reported 25-Nov-2017  2017  Sea Disaster       LIBYA
# 691     692           01-Feb-2017  2017    Watercraft         USA
# ...     ...                   ...   ...           ...         ...
# 6672   6698         Reported 1637  1637    Unprovoked       INDIA
# 6673   6699         Reported 1617  1617    Unprovoked       INDIA
# 6712   6740           Before 1963  0000    Unprovoked    DJIBOUTI
# 6722   6750           Before 2004  0000    Watercraft  MOZAMBIQUE
# 6796   6825           Before 1917  0000    Unprovoked        FIJI
#
#      Update Countries                Area                  Location  \
# 194               USA      North Carolina               Outer Banks
# 259         AUSTRALIA     New South Wales                   Forster
# 274         AUSTRALIA            Tasmania              Tenth Island
# 569             LIBYA                 NaN            Gars Garabulli
# 691               USA      South Carolina  16 miles off Hilton Head
# ...               ...                 ...                       ...
# 6672            INDIA         West Bengal       Hooghly River mouth
# 6673            INDIA         West Bengal              Ganges Delta
# 6712         DJIBOUTI    Gulf of Tadjoura                       NaN
# 6722       MOZAMBIQUE  Inhambane Province             Off Inhambane
# 6796             FIJI        Moala Island                       NaN
#
#                                                Activity  \
# 194                                      Tagging sharks
# 259   Fishing / Filming sharks feeding on whale carcass
# 274                                         Sightseeing
# 569                                    2 boats capsized
# 691                                             Fishing
# ...                                                 ...
# 6672                                             Wading
# 6673                                                NaN
# 6712                                    A dhow capsized
# 6722                                            Fishing
# 6796               Wreck of  large double sailing canoe
#
#                                                    Name Sex   Age  \
# 194                            fishing boat Sarah Brent  NaN  NaN
# 259                               Occupant: Dean Butler  NaN  NaN
# 274       5.5 m runabout. Occupants: Sean & James Vinar  NaN  NaN
# 569                                         31 migrants  NaN  NaN
# 691               Tagging sharks, Chip Michelove & crew  NaN  NaN
# ...                                                 ...  ...  ...
# 6672                                     Hindu pilgrims  NaN  NaN
# 6673                                      Indian people  NaN  NaN
# 6712                                   Passenger & crew  NaN  NaN
# 6722  4.8-metre skiboat, Occupants: Rod Salm & 4 fri...  NaN  NaN
# 6796                                         20 Fijians  NaN  NaN
#
#                                                  Injury Fatal (Y/N)  \
# 194   No injury to occupants, shark bit boat after b...           N
# 259               Shark bit boat, no injury to occupant           N
# 274   No injury to occupants, injury to shark attemp...         NaN
# 569                                               FATAL           Y
# 691              Shark bit boat, no injury to occupants           N
# ...                                                 ...         ...
# 6672                                                NaN     UNKNOWN
# 6673                                                NaN     UNKNOWN
# 6712                                              FATAL           Y
# 6722          No injury to occupants, shark bumped boat           N
# 6796  FATAL, 18 people  were killed by sharks, 2 sur...           Y
#
#            Time                                           Species   \
# 194         NaN                             Mako shark, 4 juvenile
# 259   Afternoon                                        White shark
# 274       09h08                                    White shark, 4m
# 569         NaN  Some drowned but other may have been killed by...
# 691         NaN                           White shark, female, 14'
# ...         ...                                                ...
# 6672        NaN                                                NaN
# 6673        NaN                                                NaN
# 6712        NaN                                                NaN
# 6722        NaN                                        Whale shark
# 6796        NaN                                                NaN
#
#                                  Investigator or Source
# 194                            News Observer, 4/29/2021
# 259                                Nine News, 8/30/2020
# 274                                      C. Black, GSAF
# 569                               TG Com 24, 11/25/2017
# 691                                   YouTube, 2/2/2017
# ...                                                 ...
# 6672        H. Edwards, p.31, citing Sebastian Manrique
# 6673            H. Edwards, p.31, citing Samuel Purchas
# 6712                                        A. C. Doyle
# 6722                    South African Shark Attack File
# 6796  Fijian Society papers presented April 17, 1918...
#
# [402 rows x 17 columns]
